# %% [markdown]
# # KNN-Classification Tutorial

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
from sklearn.datasets import load_iris

iris_dataset = load_iris()

# %%
type(iris_dataset)
# Out:
# sklearn.utils.Bunch

# %%
keys = iris_dataset.keys()
keys
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
X_df = pd.DataFrame(iris_dataset.data, columns=iris_dataset.feature_names)

# %%
X_df.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
X_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
from sklearn.model_selection import train_test_split
X_train,X_test = train_test_split(X_df, test_size=.2, random_state=25 )

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 54 to 132
# Data columns (total 4 columns):
# sepal length (cm)    120 non-null float64
# sepal width (cm)     120 non-null float64
# petal length (cm)    120 non-null float64
# petal width (cm)     120 non-null float64
# dtypes: float64(4)
# memory usage: 4.7 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 28 to 41
# Data columns (total 4 columns):
# sepal length (cm)    30 non-null float64
# sepal width (cm)     30 non-null float64
# petal length (cm)    30 non-null float64
# petal width (cm)     30 non-null float64
# dtypes: float64(4)
# memory usage: 1.2 KB

# %%
y_df= pd.Series(iris_dataset.target,)
y_train,y_test = train_test_split(y_df, test_size=.20, random_state=25)

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
y_train.shape
# Out:
# (120,)

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# ## Data Analysis using Data Visualisation tools, Particularly Seaborn

# %% [markdown]
# ### Organizing datasets

# %% [markdown]
#  Seaborn will be most powerful when your datasets have a particular organization. This format is alternately called “long-form” or “tidy” data and is described in detail by Hadley Wickham in this [academic paper](https://vita.had.co.nz/papers/tidy-data.html). The rules can be simply stated:
#
# - **Each variable is a column**
#
# - **Each observation is a row**
#
# A helpful mindset for determining whether your data are tidy is to think backwards from the plot you want to draw. From this perspective, a “variable” is something that will be assigned a role in the plot. It may be useful to look at the example datasets and see how they are structured. For example, the first five rows of the “iris” dataset look like ,shown above

# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
sns.distplot(iris.sepal_length)

# %%
sns.scatterplot(x="sepal_length",y="sepal_width", hue="species", data=iris)

# %%
sns.scatterplot(x="petal_length",y="petal_width", hue="species", data=iris)

# %%
sns.pairplot(data=iris, hue="species")

# %%
sns.catplot(x="species", y="petal_length", hue="species",
            kind="swarm", data=iris)

# %%
sns.catplot(x="species", y="petal_width", hue="species",
            kind="swarm", data=iris)

# %%
sns.catplot(x="species", y="sepal_length", hue="species",
            kind="swarm", data=iris)

# %%
sns.catplot(x="species", y="sepal_width", hue="species",
            kind="swarm", data=iris)

# %%
sns.catplot(x="species", y="sepal_length", hue="species",
            kind="violin",  data=iris)

# %%
sns.catplot(x="species", y="sepal_length", hue="species",
            kind="bar", data=iris, legend="full")

# %% [markdown]
# #### Using Diffierent Themes and color paletts for customising

# %%
sns.set(style="ticks", palette="muted")

# %%
sns.relplot(x="petal_length", y="petal_width", col="species",
            hue="species", data=iris)
